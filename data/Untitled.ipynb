# %%
import pandas as pd
pages = pd.read_csv('electiondata.csv')
pages[pages['constituency'] == 'Andaman & Nicobar Islands(1)']
# Out:
#     ref                      state                  constituency  \
# 38   39  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 39   40  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 40   41  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 41   42  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 42   43  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 43   44  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 44   45  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 45   46  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 46   47  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 47   48  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 48   49  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 49   50  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 50   51  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
#
# ...
