# %%
import pandas as pd
import numpy as np
df = pd.read_csv('electiondata4.csv')
print(df)
# Out:
#        ref                      state                  constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# ...    ...                        ...                           ...
# 8897  8898             Andhra Pradesh                 Srikakulam(2)
# 8898  8899             Andhra Pradesh                 Srikakulam(2)
# 8899  8900             Andhra Pradesh                 Srikakulam(2)
# 8900  8901             Andhra Pradesh                 Srikakulam(2)
# 8901  8902             Andhra Pradesh                 Srikakulam(2)
#
#                                              image_link won status   votes  \
# ...

# %%
df
# Out:
#        ref                      state                  constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# ...    ...                        ...                           ...
# 8897  8898             Andhra Pradesh                 Srikakulam(2)
# 8898  8899             Andhra Pradesh                 Srikakulam(2)
# 8899  8900             Andhra Pradesh                 Srikakulam(2)
# 8900  8901             Andhra Pradesh                 Srikakulam(2)
# 8901  8902             Andhra Pradesh                 Srikakulam(2)
#
#                                              image_link won status   votes  \
# ...

# %%
stat = ['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 
        'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli and Daman & Diu', 
        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 
        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 
        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 
        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
        'Uttarakhand', 'West Bengal']

# %%
df[df['state']=='Andhra Pradesh']
# Out:
#        ref           state       constituency  \
# 7617  7618  Andhra Pradesh  Machilipatnam(11)
# 7618  7619  Andhra Pradesh  Machilipatnam(11)
# 7619  7620  Andhra Pradesh  Machilipatnam(11)
# 7620  7621  Andhra Pradesh  Machilipatnam(11)
# 7621  7622  Andhra Pradesh  Machilipatnam(11)
# ...    ...             ...                ...
# 8897  8898  Andhra Pradesh      Srikakulam(2)
# 8898  8899  Andhra Pradesh      Srikakulam(2)
# 8899  8900  Andhra Pradesh      Srikakulam(2)
# 8900  8901  Andhra Pradesh      Srikakulam(2)
# 8901  8902  Andhra Pradesh      Srikakulam(2)
#
#                                              image_link won status   votes  \
# 7617  ['https://results.eci.gov.in/uploads4/candprof...        won  724439
# 7618  ['https://results.eci.gov.in/uploads4/candprof...       lost  501260
# 7619  ['https://results.eci.gov.in/uploads4/candprof...       lost   31825
# 7620  ['https://results.eci.gov.in/uploads4/candprof...       lost   11141
# ...

# %% [markdown]
# <h1>this is for map</h1>

# %%
sname = input("Enter a state name: ")
unique_constituencies = df[df['state'] == sname]['constituency'].unique()

# Display the unique constituency names
print("Unique constituencies:")
for constituency in unique_constituencies:
    print(constituency)
# Out:
# Enter a state name:  Andhra Pradesh
# Unique constituencies:
# Machilipatnam(11)
# Kakinada(6)
# Narsapuram(9)
# Rajahmundry(8)
# Anakapalle(5)
# Rajampet(24)
# Thirupathi(SC)(23)
# Kadapa(21)
# Araku (ST)(1)
# Chittoor(SC)(25)
# Nellore(22)
# Hindupur(20)
# Ananthapur(19)
# Kurnoolu(18)
# Nandyal(17)
# Ongole(16)
# Bapatla (SC)(15)
# Narsaraopet(14)
# Guntur(13)
# Vijayawada(12)
# Eluru(10)
# Amalapuram (SC)(7)
# Visakhapatnam(4)
# Vizianagaram(3)
# Srikakulam(2)

# %%
sname = input("Enter a state name: ")
print(f"The name of state: {sname}")
state_data = df[df['state'] == sname]
result_df = state_data[['constituency', 'Party Name', 'votes']]
result_df = result_df.drop_duplicates()
print("Constituency-wise party names and votes:")
print(result_df)
# Out:
# Enter a state name:  Andhra Pradesh
# The name of state: Andhra Pradesh
# Constituency-wise party names and votes:
#            constituency                             Party Name   votes
# 7617  Machilipatnam(11)                         Janasena Party  724439
# 7618  Machilipatnam(11)  Yuvajana Sramika Rythu Congress Party  501260
# 7619  Machilipatnam(11)               Indian National Congress   31825
# 7620  Machilipatnam(11)                 Jatiya Jana Sena Party   11141
# 7621  Machilipatnam(11)                    Bahujan Samaj Party   10028
# ...                 ...                                    ...     ...
# 8897      Srikakulam(2)              Jai Bharat National Party    1130
# 8898      Srikakulam(2)                Navarang Congress Party     818
# 8899      Srikakulam(2)                            Independent     816
# 8900      Srikakulam(2)                 Pyramid Party of India     594
# 8901      Srikakulam(2)                      None of the Above   24605
#
# ...

# %%
from geopy.geocoders import Nominatim

def get_coordinates(city, state):
    # Create a Nominatim geocoder object
    geolocator = Nominatim(user_agent="geoapiExercises")
    
    # Concatenate city and state names
    location_string = f"{city}, {state}"
    
    # Get location information
    location = geolocator.geocode(location_string)
    
    # Extract latitude and longitude
    if location:
        latitude = location.latitude
        longitude = location.longitude
        return latitude, longitude
    else:
        return None, None

# Example usage
city = "Thirupathi"
state = "Andhra Pradesh"
latitude, longitude = get_coordinates(city, state)
if latitude is not None and longitude is not None:
    print(f"Latitude: {latitude}, Longitude: {longitude}")
else:
    print("Coordinates not found for the given city and state.")
# Out:
# Latitude: 17.8152754, Longitude: 83.2067099

# %%
import folium
from geopy.geocoders import Nominatim
def get_coordinates(city, state):
    geolocator = Nominatim(user_agent="geoapiExercises")
    location_string = f"{city}, {state}"
    location = geolocator.geocode(location_string)
    if location:
        latitude = location.latitude
        longitude = location.longitude
        return latitude, longitude
    else:
        return None, None
def plot_location_on_map(city, state):
    latitude, longitude = get_coordinates(city, state)
    m = folium.Map(location=[latitude, longitude], zoom_start=10)
    folium.Marker(location=[latitude, longitude], popup=f"{city}, {state}").add_to(m)
    display(m)
city = "Thirupathi"
state = "Andhra Pradesh"
plot_location_on_map(city, state)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df.head()
# Out:
#    ref                      state                  constituency  \
# 0    1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 1    2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 2    3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 3    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 4    5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
#
#                                           image_link won status   votes  \
# 0  ['https://results.eci.gov.in/uploads4/candprof...        won  102436
# 1  ['https://results.eci.gov.in/uploads4/candprof...       lost   78040
# 2  ['https://results.eci.gov.in/uploads4/candprof...       lost    8254
# 3  ['https://results.eci.gov.in/uploads4/candprof...       lost    6017
# 4  ['https://results.eci.gov.in/uploads4/candprof...       lost    2203
#
#       (votes)                Name                           Party Name
# 0   (+ 24396)     BISHNU PADA RAY               Bharatiya Janata Party
# ...

# %%
df['votes'] = pd.to_numeric(df['votes'], errors='coerce')
states = df['state'].unique()
state_name = input("Enter the name of the state: ")
if state_name in states:
    print(f"State: {state_name}")
    df_state = df[df['state'] == state_name]
    constituencies = sorted(df_state['constituency'].unique())
    for constituency in constituencies:
        df_constituency = df_state[df_state['constituency'] == constituency]
        df_constituency = df_constituency.sort_values(by='votes', ascending=False)
        print(f"\tConstituency: {constituency}")
        for index, row in df_constituency.iterrows():
            print(f"\t\tParty: {row['Party Name']}, Candidate: {row['Name']}, Votes: {row['votes']}")
else:
    print("State not found in the data.")
# Out:
# Enter the name of the state:  Andhra Pradesh
# State: Andhra Pradesh
# 	Constituency: Amalapuram (SC)(7)
# 		Party: Telugu Desam, Candidate: G M HARISH (BALAYOGI), Votes: 796981.0
# 		Party: Yuvajana Sramika Rythu Congress Party, Candidate: RAPAKA VARAPRASADA RAO, Votes: 454785.0
# 		Party: Indian National Congress, Candidate: GOUTHAM JANGA, Votes: 15082.0
# 		Party: None of the Above, Candidate: NOTA, Votes: 13518.0
# 		Party: Bahujan Samaj Party, Candidate: DORABABU YALLA, Votes: 5388.0
# 		Party: Telugu Nava Garjana Party, Candidate: KATRU NAGA BABU, Votes: 3741.0
# 		Party: Independent, Candidate: VADDI LALITH KUMAR, Votes: 2977.0
# 		Party: Independent, Candidate: MAKEY DAVY PRASAD, Votes: 2111.0
# 		Party: Independent, Candidate: GUDE VENKATESWARULU, Votes: 1745.0
# 		Party: Jatiya Jana Sena Party, Candidate: RAMESH JILLELLA, Votes: 872.0
# 		Party: Jaibhim Rao Bharat Party, Candidate: YALANGI RAMESH, Votes: 740.0
# ...

# %%
df_constituency
# Out:
#        ref           state     constituency  \
# 8872  8873  Andhra Pradesh  Vizianagaram(3)
# 8873  8874  Andhra Pradesh  Vizianagaram(3)
# 8887  8888  Andhra Pradesh  Vizianagaram(3)
# 8874  8875  Andhra Pradesh  Vizianagaram(3)
# 8875  8876  Andhra Pradesh  Vizianagaram(3)
# 8876  8877  Andhra Pradesh  Vizianagaram(3)
# 8877  8878  Andhra Pradesh  Vizianagaram(3)
# 8878  8879  Andhra Pradesh  Vizianagaram(3)
# 8879  8880  Andhra Pradesh  Vizianagaram(3)
# 8880  8881  Andhra Pradesh  Vizianagaram(3)
# 8881  8882  Andhra Pradesh  Vizianagaram(3)
# 8882  8883  Andhra Pradesh  Vizianagaram(3)
# 8883  8884  Andhra Pradesh  Vizianagaram(3)
# 8884  8885  Andhra Pradesh  Vizianagaram(3)
# 8885  8886  Andhra Pradesh  Vizianagaram(3)
# 8886  8887  Andhra Pradesh  Vizianagaram(3)
#
#                                              image_link won status     votes  \
# 8872  ['https://results.eci.gov.in/uploads4/candprof...        won  743113.0
# ...
